# %%
import os
import requests
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.google.com/search?q=car&tbm=isch&chips=q:car,g_1:lamborghini:OtBvb9Jh2II%3D&rlz=1C1CHBF_enIN1017IN1017&hl=en-GB&sa=X&ved=2ahUKEwismsPLsqODAxW-SWwGHaZWCmkQ4lYoAHoECAEQMw&biw=1349&bih=645"  

response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

image_tags = soup.find_all('img')

src_list = [img['src'] for img in image_tags if 'src' in img.attrs]
https_links = [link for link in src_list if link.startswith('https://')]

# %%
https_links
# Out:
# ['https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTOlFtyRH4ZxCiW3ar11APHWiaIFqtdjfoV3RhRrypJ9EuAgAmfZ7-i7yO6H3s&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTIWqVUYbhaOhqiqMCr-V-vZp5UXFZ__iztCyeyxBa0mvRbOz3TZOy_nJPYHQ&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQt8YLcjXUucTqieW7unvtNIVjTMi0UzkLUIzDVSTbhMtW2PJ6lDwmuATSUiyk&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHSDo1RyvHCzahQI0Zm1qLU4-Vl4Z0ZfETN1Cne-ej1v-A6k7oCkUIAsAlhis&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSD-1CbCeXYZYLt9qiS2AtTYRq--SKI4_FYWuzBg0ubhFQUTFz1XkatLAxt5PY&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTVA6WNEbGnE6SOvzB6esgboYUEHQFoDtUXrqs3WLEUtMMURMjJpNVAOSSb1A&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR6VobDvgdpehFT53DOrl-cUZv3KefQnPJYclWroLSzgnwh2rIMA4bIZCatEa0&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTXE37zD_ZxozkyNWgPf-75LMvcSwA_XRKBrCobktrCX30__s07VHHug-IyQg&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQmgXYr6xFJUOyznSvHrCdyLy6tt6VV89KUePqCgh8Wcj_377eNL1H7iElLW0M&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSlya8zkV-V19Ci5z9JXtjEoO8RD_-A-YRf7f9dlZgx8zGAykpbG4WadqlPaQ&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQGqvJQtxjEfuzNxqnqKuPNr2i1HrRKH9VfZLsciJQhI4ieqZz1Uku8EwubBkw&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTWFY1eGXLjyvtkz1aQIau7sdKOUWKzxOkCVExlmOPboeZeTqLjKuN9hXVwgA&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSrjObrI0oTKKPRys8tJRWJFo_-b9pf-mUcxewbQdqYdIse8zQ6HLPP1DaYDQ&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSyOleUtTrRwXvVQHBaXJDatJzCP_PoD5-QDdSxs9X2DhxzcN6wq_BGW5JEqzg&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRK7geCMwFHGieOGAyw6huYiE4N9-xIP8AEv66bNWv2rNoOhfnriZz7fh3hOA&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQo36XVG_VvonnP9UBo_w7d0n5_HyD24aFDn9EBL6olXbBajroc7sKiuhe0rSM&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbJAYyev4pHHSJiZ8PVm4MN5kf-3pygtlqYFVaRkdzWDmpr6vswyHCP-lVeQ&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSFDtAzp2evlT_TQHo6xDoDHreUZ5Bia14P2u7dOF41CKb7I6iXaa2LIPG5A&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQN6cQ3eO2rM1Um02W87oF8Vcj8FZadIc9V3I_wVg2PSetx4d_n3l8UbBzBuA8&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRHBepcRnUXO8KvwEdiUa5Xn1a3BlXd-9u9lp2eW4rtO6Tq6RaUx0CIVq8CfA&s']

# %%
image_details = []

if not os.path.exists('images'):
    os.makedirs('images')

for index, url in enumerate(https_links, start=1):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            image_name = f'image{index}.jpg'
            image_path = f'images/{image_name}'
            with open(image_path, 'wb') as file:
                file.write(response.content)
                print(f"Image {index} downloaded successfully.")
                image_details.append({'Image Name': image_name, 'Image Path': image_path})
        else:
            print(f"Failed to download Image {index}. Status code: {response.status_code}")
    except Exception as e:
        print(f"Error downloading Image {index}: {e}")

df_images = pd.DataFrame(image_details)
# Out:
# Image 1 downloaded successfully.
# Image 2 downloaded successfully.
# Image 3 downloaded successfully.
# Image 4 downloaded successfully.
# Image 5 downloaded successfully.
# Image 6 downloaded successfully.
# Image 7 downloaded successfully.
# Image 8 downloaded successfully.
# Image 9 downloaded successfully.
# Image 10 downloaded successfully.
# Image 11 downloaded successfully.
# Image 12 downloaded successfully.
# Image 13 downloaded successfully.
# Image 14 downloaded successfully.
# Image 15 downloaded successfully.
# Image 16 downloaded successfully.
# Image 17 downloaded successfully.
# Image 18 downloaded successfully.
# Image 19 downloaded successfully.
# Image 20 downloaded successfully.

# %%
df_images
# Out:
#      Image Name          Image Path
# 0    image1.jpg   images/image1.jpg
# 1    image2.jpg   images/image2.jpg
# 2    image3.jpg   images/image3.jpg
# 3    image4.jpg   images/image4.jpg
# 4    image5.jpg   images/image5.jpg
# 5    image6.jpg   images/image6.jpg
# 6    image7.jpg   images/image7.jpg
# 7    image8.jpg   images/image8.jpg
# 8    image9.jpg   images/image9.jpg
# 9   image10.jpg  images/image10.jpg
# 10  image11.jpg  images/image11.jpg
# 11  image12.jpg  images/image12.jpg
# 12  image13.jpg  images/image13.jpg
# 13  image14.jpg  images/image14.jpg
# 14  image15.jpg  images/image15.jpg
# 15  image16.jpg  images/image16.jpg
# 16  image17.jpg  images/image17.jpg
# 17  image18.jpg  images/image18.jpg
# 18  image19.jpg  images/image19.jpg
# 19  image20.jpg  images/image20.jpg

# %%
import matplotlib.pyplot as plt
import os

def display_images(image_paths):
    num_images = len(image_paths)
    num_cols = 4 
    num_rows = (num_images - 1) // num_cols + 1

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 18))

    for i, ax in enumerate(axes.flat):
        if i < num_images:
            img = plt.imread(image_paths[i])
            ax.imshow(img)
            ax.axis('off')
        else:
            ax.axis('off')  

    plt.tight_layout()
    plt.show()

image_paths = df_images['Image Path'].tolist()

display_images(image_paths)
